# %%
from stlab.devices.IVVI import IVVI_DAC

# %%
dev = IVVI_DAC('COM1')
# Out:
# [<pol.bipolar: 'BIP'>, <pol.bipolar: 'BIP'>]
# Polarity settings
# DACs 1-4: BIP
# DACs 5-8: BIP
# polmatrix =  (2000.0, 2000.0, 2000.0, 2000.0, 2000.0, 2000.0, 2000.0, 2000.0)

# %%
dev.ReadDACs()
# Out:
# DAC input:  (4, 0, 18, 2)
# DAC reply:  (18, 0, 128, 0, 128, 0, 128, 0, 128, 0, 128, 0, 128, 0, 128, 0, 128, 0)
# (0.03051804379333589,
#  0.03051804379333589,
#  0.03051804379333589,
#  0.03051804379333589,
#  0.03051804379333589,
#  0.03051804379333589,
#  0.03051804379333589,
#  0.03051804379333589)

# %%
dev.RampAllZero()
# Out:
# DAC input:  (4, 0, 18, 2)
# DAC reply:  (18, 0, 130, 184, 128, 0, 128, 0, 128, 0, 128, 0, 128, 0, 128, 0, 128, 0)
# DAC input:  (7, 0, 2, 1, 1, 130, 184)
# DAC reply:  (2, 0)
# DAC 1 set to 42.51163500419602 mV
# DAC input:  (7, 0, 2, 1, 2, 128, 0)
# DAC reply:  (2, 0)
# DAC 2 set to 0.03051804379333589 mV
# DAC input:  (7, 0, 2, 1, 3, 128, 0)
# DAC reply:  (2, 0)
# DAC 3 set to 0.03051804379333589 mV
# DAC input:  (7, 0, 2, 1, 4, 128, 0)
# DAC reply:  (2, 0)
# DAC 4 set to 0.03051804379333589 mV
# DAC input:  (7, 0, 2, 1, 5, 128, 0)
# DAC reply:  (2, 0)
# DAC 5 set to 0.03051804379333589 mV
# DAC input:  (7, 0, 2, 1, 6, 128, 0)
# DAC reply:  (2, 0)
# DAC 6 set to 0.03051804379333589 mV
# DAC input:  (7, 0, 2, 1, 7, 128, 0)
# DAC reply:  (2, 0)
# DAC 7 set to 0.03051804379333589 mV
# DAC input:  (7, 0, 2, 1, 8, 128, 0)
# DAC reply:  (2, 0)
# DAC 8 set to 0.03051804379333589 mV
# DAC input:  (7, 0, 2, 1, 1, 130, 177)
# DAC reply:  (2, 0)
# DAC 1 set to 42.08438239108864 mV
# ...

# %%
dev.SetPolarity(('BIP','BIP'))

# %%
dev.close()

# %%
dev.RampVoltage_TimeSteps??

# %%
import numpy as np
np.linspace(0.85,0.85,1001)
# Out:
# array([ 0.85,  0.85,  0.85, ...,  0.85,  0.85,  0.85])
